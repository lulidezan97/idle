# %% [markdown]
# # Análisis de texto

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF, TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from wordcloud import WordCloud
from nltk.corpus import stopwords
import string
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from nltk.tokenize import word_tokenize
from collections import Counter
from PIL import Image, ImageDraw, ImageFont

# %%
from nltk.util import ngrams

# %%
df = pd.read_csv('https://raw.githubusercontent.com/meyersebastian/idle/master/version1407.csv',encoding='utf-8')
#df = pd.read_csv('version1407.csv',encoding='utf-8')

# %%
#df.head()
# Out:
#   submission_date  genero                edad  \
# 0      28/06/2020  Hombre  Entre 56 y 65 años
# 1      28/06/2020  Hombre      Más de 66 años
# 2      28/06/2020  Hombre      Más de 66 años
# 3      28/06/2020  Hombre      Más de 66 años
# 4      28/06/2020  Hombre  Entre 56 y 65 años
#
#                        donde_vivis                         opinion_cuarentena  \
# 0        provincia de buenos aires   La cuarentena sigue siendo muy necesaria
# 1                        rio negro      La cuarentena ya no es nada necesaria
# 2        provincia de buenos aires       La cuarentena ya no es tan necesaria
# 3        provincia de buenos aires  La cuarentena sigue siendo algo necesaria
# 4  ciudad autonoma de buenos aires   La cuarentena sigue siendo muy necesaria
#
#                home_office    act_original  \
# 0    No trabajo ni estudio             NaN
# 1    No trabajo ni estudio        jubilado
# 2    No trabajo ni estudio             NaN
# 3  Si, pude hacerlo online  bailo folclore
# 4  Si, pude hacerlo online             NaN
#
#                                  opinion_circulacion  \
# 0  Estoy muy en desacuerdo con que se pueda volve...
# 1  Estoy muy de acuerdo con que se pueda volver a...
# 2  Estoy algo en desacuerdo con que se pueda volv...
# 3  Estoy algo en desacuerdo con que se pueda volv...
# 4  Estoy algo de acuerdo con que se pueda volver ...
#
#                  circulacion_abierta submitter  \
# 0                                NaN       NaN
# 1                                NaN       NaN
# 2                          esta bien       NaN
# 3  debe ser estrictamente controlada       NaN
# 4                                NaN       NaN
#
#                                    filepath             act_limpia  \
# 0  1980d430-bfc4-11ea-9f59-9197db17f01d.csv                    NaN
# 1  1980d430-bfc4-11ea-9f59-9197db17f01d.csv               jubilado
# 2  1980d430-bfc4-11ea-9f59-9197db17f01d.csv                    NaN
# 3  1980d430-bfc4-11ea-9f59-9197db17f01d.csv  ['bailo', 'folclore']
# 4  1980d430-bfc4-11ea-9f59-9197db17f01d.csv                    NaN
#
#                                       circ_limpia Profesion
# 0                                             NaN       NaN
# 1                                             NaN  jubilado
# 2                                ['esta', 'bien']       NaN
# 3  ['debe', 'ser', 'estrictamente', 'controlada']  bailarin
# 4                                             NaN       NaN

# %%
opinion_circulacion = df.loc[df.circulacion_abierta.notnull(),'circulacion_abierta']

# %%
def limpiar(x):
    x=x.lower()
    x=x.replace('\n','')
    x=x.replace('á','a')
    x=x.replace('é','e')
    x=x.replace('í','i')
    x=x.replace('ó','o')
    x=x.replace('ú','u')
    x = x.strip(' ')
    x = ' '.join(x.split('\\n'))
    x = ' '.join(x.split('\n'))
    for signo in list(string.punctuation):
        x = ' '.join(x.split(signo))
    x = x.replace('  ',' ')
    return x

# %%
opinion_circulacion=pd.DataFrame(opinion_circulacion)

# %%
opinion_circulacion['Limpia'] = [limpiar(x) for x in opinion_circulacion.circulacion_abierta]

# %%
stop=stopwords.words('spanish')

# %% [markdown]
# ## Wordcloud

# %%
values = ','.join(str(v) for v in opinion_circulacion['Limpia'])
word_tokens = word_tokenize(values)
word_tokens = [w.strip(' ') for w in word_tokens]
filtered_sentence = [w for w in word_tokens if not w in stop]
wc=WordCloud(background_color="white",collocations=True).generate(' '.join(filtered_sentence))
plt.imshow(wc, interpolation="bilinear")
#plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title('Circulación entre provincias')
plt.rcParams['figure.figsize'] = [10,10]
plt.show()

# %%
filtered_sentence = [w for w in filtered_sentence if not w in list(string.punctuation)] 
counts = Counter(filtered_sentence)
doble_counts = Counter(ngrams(filtered_sentence,2))
triple_counts = Counter(ngrams(filtered_sentence,3))
#print('De a una')
#for o in range(len(counts.most_common(10))):
#    print("La palabra " +str(counts.most_common(10)[o][0])+" aparece "+str(counts.most_common(10)[o][1])+" veces")
#print('--------------------')
#print('De a dos')
#for i in range(len(doble_counts.most_common(10))):
#    print("Las palabras " +str(' '.join(list(doble_counts.most_common(10)[i][0])))+" aparecen "+str(doble_counts.most_common(10)[i][1])+" veces")
#print('--------------------')
#print('De a tres')
#for a in range(len(triple_counts.most_common(10))):
#    print("Las palabras " +str(' '.join(list(triple_counts.most_common(10)[a][0])))+" aparecen "+str(triple_counts.most_common(10)[a][1])+" veces")
#print('--------------------')
# Out:
# De a una
# La palabra provincias aparece 148 veces
# La palabra circulacion aparece 125 veces
# La palabra virus aparece 112 veces
# La palabra si aparece 106 veces
# La palabra mas aparece 95 veces
# La palabra casos aparece 69 veces
# La palabra bien aparece 57 veces
# La palabra debe aparece 52 veces
# La palabra provincia aparece 52 veces
# La palabra q aparece 52 veces
# --------------------
# De a dos
# Las palabras circulacion provincias aparecen 26 veces
# Las palabras bs as aparecen 15 veces
# Las palabras parece bien aparecen 14 veces
# Las palabras buenos aires aparecen 14 veces
# Las palabras covid 19 aparecen 14 veces
# Las palabras debe ser aparecen 13 veces
# Las palabras circulacion virus aparecen 13 veces
# Las palabras circular provincias aparecen 12 veces
# Las palabras circulacion viral aparecen 10 veces
# Las palabras solo provincias aparecen 9 veces
# --------------------
# De a tres
# Las palabras tomando recaudos necesarios aparecen 4 veces
# Las palabras gente necesita trabajar aparecen 4 veces
# Las palabras provincia buenos aires aparecen 4 veces
# Las palabras haber circulacion provincias aparecen 3 veces
# Las palabras mas 100 dias aparecen 3 veces
# Las palabras 100 dias cuarentena aparecen 3 veces
# Las palabras casos positivos covid aparecen 3 veces
# Las palabras puede circular provincias aparecen 3 veces
# Las palabras bien debe ser aparecen 2 veces
# Las palabras circulacion solo provincias aparecen 2 veces
# --------------------

# %% [markdown]
# ## Summarization

# %%
import spacy
from spacy.lang.es.stop_words import STOP_WORDS
import es_core_news_sm
from sklearn.feature_extraction.text import CountVectorizer

# %%
nlp = spacy.load('es_core_news_sm')

# %%
texto='.fin_oracion '.join(opinion_circulacion.circulacion_abierta)
doc = nlp(texto)
texto_split=texto.split('.fin_oracion ')
texto_split=[x.lower() for x in texto_split]
cv = CountVectorizer(stop_words=list(STOP_WORDS))   
cv_fit=cv.fit_transform(texto_split)    
word_list = cv.get_feature_names();    
count_list = cv_fit.toarray().sum(axis=0)
word_frequency = dict(zip(word_list,count_list))
val=sorted(word_frequency.values())
higher_word_frequencies = [word for word,freq in word_frequency.items() if freq in val[-5:]]
print("Las palabras más frecuentes del documento son " + ', '.join(higher_word_frequencies[:-1])+' y '+higher_word_frequencies[-1])
# gets relative frequencies of words
higher_frequency = val[-1]
for words in word_frequency.keys():  
    word_frequency[words] = (word_frequency[words]/higher_frequency)
sentence_rank={}
for sent in texto_split:
    for word in sent.split() :       
        if word in word_frequency.keys():            
            if sent in sentence_rank.keys():
                sentence_rank[sent]+=word_frequency[word]
            else:
                sentence_rank[sent]=word_frequency[word]
top_sentences=(sorted(sentence_rank.values())[::-1])
top_sent=top_sentences[:30]
summary=[]
strength_lista = []
for sentence,strength in sentence_rank.items():  
    if strength in top_sent:
        summary.append(sentence)
        strength_lista.append(strength)
    else:
        continue
df_sent=pd.DataFrame(list(zip(summary,strength_lista)),columns=['Sentence','Score'])
df_sent=df_sent.sort_values(by=['Score'],ascending=False).reset_index()
numero=0
print('\n')
print('Algunas respuestas representativas son: ')
print('\n')
for i in range(len(df_sent)):
    if numero<3:    
        if (len(df_sent.Sentence[i])>30)&(len(df_sent.Sentence[i])<1000):
            print('- '+df_sent.Sentence[i])
            numero+=1
            print('\n')
    else:
        break
# Out:
# Las palabras más frecuentes son casos, circulacion, provincia, provincias y virus
#
#
# Algunas respuestas representativas son:
#
#
# - creo que despues de 100 dias de cuarentena, ya deberia estar habilitada la circulacion en micros de larga distancia asi como en auto, sobre todo entre provincias que ya alcanzaron la fase 5, o entre ciudades o localidades tambien en fase 5.  solo no estaria de acuerdo en el contacto de provincias de fase 5 con otras que estan en una fase inferior. no me parece justo que en donde hicimos las cosas bien debamos seguir esperando que habran las provincias o que habiliten los micros de larga distancia por culpa de una sola provincia que hicieron todo mal.
#
#
# - deberia tomarse en cuenta que si hay localidades limitrofes donde no hay circulacion del virus y que sean de provincias distintas, tranquilamente podrian circular las personas en esas localidades y a tambien ir a las ciudades capitales donde el virus este manejado
#
#
# - me encantaria viajar a la patagonia donde vive uno de los hijos, pero siendo q caba esta tan poblada de gente infectada por el virus, la circulacion hacia alla seria terrible x el posible contagio. hasta q no haya casos no. pero la circulacion entre provincias q no tienen casos la veo muy bien, obviamente

# %% [markdown]
# ## LDA - Búsqueda de tópicos

# %%
def palabras_clave(x):
    doc = nlp(x)
    palabras = [(token.pos_,token.text) for token in doc]
    #print(palabras)
    palabras_utiles = [x[1] for x in palabras if x[0] in ['ADJ','NOUN','NUM','VERB','PRON','PROPN','PART']]
    return ' '.join(palabras_utiles)

# %%
def lemas_verbo(x):
    doc = nlp(x)
    palabras = [(token.pos_,token.lemma_,token.text) for token in doc]
    palabras_lema = [x[1] if x[0] == 'VERB' else x[2] for x in palabras]# if x[0] in ['ADJ','NOUN','NUM','PRON','PROPN','VERB','PART']]
    return ' '.join(palabras_lema)

# %%
opinion_circulacion['Limpia 2'] = opinion_circulacion['circulacion_abierta'].apply(lambda x: palabras_clave(x))

# %%
opinion_circulacion['Limpia 2'] = opinion_circulacion['Limpia 2'].apply(lambda x: lemas_verbo(x))

# %%
from gensim.models.ldamodel import LdaModel

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(opinion_circulacion['Limpia 2']))

#print(data_words[:1])

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
#print(trigram_mod[bigram_mod[data_words[0]]])

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
# Form Bigrams
data_words_bigrams = make_bigrams(data_words)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
#nlp = spacy.load('es_core_news_sm', disable=['parser', 'ner'])

#print(data_words_bigrams[2])

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_words_bigrams)

# Create Corpus
texts = data_words_bigrams

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
#print(corpus[:5])

# %%
for i in range(3,12):    
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                               id2word=id2word,
                                               num_topics=i, 
                                               random_state=100,
                                               update_every=1,
                                               chunksize=100,
                                               passes=10,
                                               alpha=0.5,
                                               per_word_topics=True)
    df_palabras_topico =pd.DataFrame()
    for topico in lda_model.print_topics(num_words=6):
        #print(i[1])
        #print(i[1].split(' + '))
        palabras_topico=topico[1].split(' + ')
        array_palabras=[x.split('*')[1] for x in palabras_topico]
        df_palabras_topico['Topico '+str(topico[0])]=array_palabras
    doc_lda = lda_model[corpus]
    #print('Topicos '+str(topico[0]+1))
    #display(df_palabras_topico)
# Out:
# Topicos 3
#        Topico 0      Topico 1       Topico 2
# 0          "se"         "que"           "se"
# 1   "controles"       "hacer"   "provincias"
# 2   "necesario"   "provincia"        "virus"
# 3       "tomar"        "todo"  "circulacion"
# 4  "necesarios"         "nos"        "tener"
# 5         "que"  "cuarentena"        "casos"
# Topicos 4
#        Topico 0      Topico 1       Topico 2      Topico 3
# 0          "se"         "que"           "se"         "que"
# 1   "controles"       "hacer"   "provincias"       "tener"
# 2   "necesario"       "gente"        "virus"       "covid"
# 3    "contagio"  "cuarentena"  "circulacion"  "protocolos"
# 4       "tomar"         "nos"        "casos"          "me"
# 5  "necesarios"      "riesgo"     "circular"     "control"
# Topicos 5
#        Topico 0      Topico 1       Topico 2      Topico 3     Topico 4
# 0   "controles"          "se"   "provincias"       "tener"        "que"
# 1       "tomar"    "contagio"           "se"         "que"  "necesario"
# 2  "necesarios"  "cuarentena"  "circulacion"          "me"      "hacer"
# 3          "se"      "riesgo"        "virus"   "provincia"      "estan"
# 4          "ir"       "hacer"        "casos"       "covid"        "ver"
# 5    "recaudos"       "seria"     "circular"  "protocolos"     "llevar"
# Topicos 6
#        Topico 0        Topico 1       Topico 2      Topico 3      Topico 4  \
# 0   "controles"     "necesario"   "provincias"       "tener"         "que"
# 1       "tomar"      "contagio"  "circulacion"         "que"       "hacer"
# 2  "necesarios"         "seria"        "virus"       "covid"          "se"
# 3          "ir"         "gente"           "se"  "protocolos"      "querer"
# 4    "recaudos"         "libre"        "casos"     "control"  "cuarentena"
# 5          "se"  "buenos_aires"          "mas"        "bien"       "estan"
#
#       Topico 5
# 0         "se"
# 1   "circular"
# 2        "que"
# 3         "me"
# 4  "provincia"
# 5       "todo"
# Topicos 7
#        Topico 0     Topico 1       Topico 2     Topico 3  Topico 4  \
# 0   "controles"  "necesario"   "provincias"      "covid"     "que"
# 1       "tomar"   "contagio"  "circulacion"    "control"  "querer"
# 2  "necesarios"      "seria"           "se"        "que"   "hacer"
# 3          "se"   "economia"        "casos"  "necesitar"   "estan"
# 4          "ir"      "gente"        "tener"       "bien"     "ver"
# 5     "acuerdo"      "libre"          "mas"      "cosas"  "llevar"
#
#       Topico 5      Topico 6
# 0   "circular"       "virus"
# 1         "me"          "se"
# 2        "que"        "todo"
# 3  "provincia"        "solo"
# 4         "se"  "protocolos"
# 5    "deberia"       "donde"
# Topicos 8
#        Topico 0     Topico 1       Topico 2 Topico 3  Topico 4     Topico 5  \
# 0          "se"  "necesario"   "provincias"   "bien"     "que"         "me"
# 1   "controles"      "seria"  "circulacion"  "cosas"   "estan"        "que"
# 2       "tomar"         "se"           "se"  "bs_as"     "ver"    "deberia"
# 3  "necesarios"   "economia"        "casos"   "caso"  "llevar"     "riesgo"
# 4     "acuerdo"      "gente"        "virus"  "salta"    "esto"         "se"
# 5          "ir"      "libre"          "mas"  "chaco"   "gente"  "provincia"
#
#       Topico 6      Topico 7
# 0       "solo"    "circular"
# 1       "todo"       "tener"
# 2      "donde"    "contagio"
# 3      "virus"         "que"
# 4  "provincia"       "hacer"
# 5      "covid"  "cuarentena"
# Topicos 9
#        Topico 0     Topico 1       Topico 2    Topico 3  Topico 4    Topico 5  \
# 0          "se"  "necesario"   "provincias"   "control"     "que"        "me"
# 1   "controles"      "seria"  "circulacion"      "bien"      "se"   "deberia"
# 2       "tomar"         "se"        "casos"  "trabajar"  "querer"    "riesgo"
# 3  "necesarios"      "gente"           "se"  "estricto"   "estan"        "se"
# 4     "acuerdo"   "economia"        "tener"     "estar"  "llevar"  "pandemia"
# 5          "ir"      "libre"          "mas"       "nop"    "esto"       "mas"
#
#        Topico 6      Topico 7     Topico 8
# 0        "todo"       "virus"      "tener"
# 1       "donde"    "circular"        "nos"
# 2       "covid"    "contagio"        "que"
# 3  "protocolos"   "provincia"         "se"
# 4        "solo"       "hacer"     "pensar"
# 5       "virus"  "cuarentena"  "provincia"
# Topicos 10
#        Topico 0       Topico 1       Topico 2    Topico 3     Topico 4  \
# 0       "tomar"           "se"   "provincias"   "control"        "que"
# 1  "necesarios"  "circulacion"        "tener"      "bien"  "necesario"
# 2     "acuerdo"        "seria"        "casos"  "estricto"     "querer"
# 3       "gente"     "economia"  "circulacion"   "isieron"      "estan"
# 4          "ir"        "gente"         "solo"       "nop"     "llevar"
# 5          "se"        "libre"    "contagios"  "perfecto"       "esto"
#
#         Topico 5      Topico 6       Topico 7   Topico 8     Topico 9
# 0           "me"   "controles"        "virus"      "nos"        "que"
# 1     "personas"        "todo"           "se"   "pensar"   "contagio"
# 2      "deberia"       "donde"     "circular"    "tener"      "hacer"
# 3        "salud"       "covid"          "mas"      "mas"         "se"
# 4  "circulacion"  "protocolos"   "provincias"   "tiempo"  "provincia"
# 5    "provincia"         "ver"  "circulacion"  "todavia"    "momento"
# Topicos 11
#        Topico 0       Topico 1      Topico 2     Topico 3     Topico 4  \
# 0       "tomar"  "circulacion"       "tener"    "control"        "que"
# 1  "necesarios"   "provincias"       "casos"       "bien"     "querer"
# 2       "gente"          "mas"        "solo"   "estricto"      "estan"
# 3     "acuerdo"           "se"   "necesaria"    "isieron"     "llevar"
# 4          "ir"        "seria"  "provincias"        "nop"  "peligroso"
# 5    "recaudos"     "economia"         "una"  "necesidad"     "viajar"
#
#       Topico 5      Topico 6           Topico 7    Topico 8      Topico 9  \
# 0         "me"   "controles"               "se"       "nos"    "contagio"
# 1  "provincia"        "todo"            "virus"    "pensar"       "hacer"
# 2   "personas"       "donde"       "provincias"  "libertad"     "momento"
# 3    "tendria"       "covid"         "circular"     "tener"  "cuarentena"
# 4     "parece"  "protocolos"            "resto"    "tiempo"     "deberia"
# 5         "la"         "ver"  "responsabilidad"   "todavia"      "riesgo"
#
#         Topico 10
# 0     "necesario"
# 1     "contagios"
# 2      "pandemia"
# 3        "evitar"
# 4         "salud"
# 5  "buenos_aires"

# %%
# Print the Keyword in the 10 topics
df_palabras_topico =pd.DataFrame()
for i in lda_model.print_topics(num_words=10):
    #print(i[1])
    #print(i[1].split(' + '))
    palabras_topico=i[1].split(' + ')
    array_palabras=[x.split('*')[1] for x in palabras_topico]
    df_palabras_topico['Topico '+str(i[0])]=array_palabras
doc_lda = lda_model[corpus]

# %%
#df_palabras_topico
# Out:
#        Topico 0       Topico 1      Topico 2     Topico 3      Topico 4  \
# 0       "tomar"  "circulacion"       "tener"    "control"         "que"
# 1  "necesarios"   "provincias"       "casos"       "bien"      "querer"
# 2       "gente"          "mas"        "solo"   "estricto"       "estan"
# 3     "acuerdo"           "se"   "necesaria"    "isieron"      "llevar"
# 4          "ir"        "seria"  "provincias"        "nop"   "peligroso"
# 5    "recaudos"     "economia"         "una"  "necesidad"      "viajar"
# 6    "trabajar"        "libre"      "seguir"   "perfecto"     "tambien"
# 7   "necesitar"         "pais"   "situacion"      "falto"      "libres"
# 8    "cuidados"    "fronteras"     "peligro"     "peores"        "otro"
# 9       "saber"    "afectadas"       "pocos"    "mudanza"  "familiares"
#
#       Topico 5      Topico 6           Topico 7    Topico 8      Topico 9  \
# 0         "me"   "controles"               "se"       "nos"    "contagio"
# 1  "provincia"        "todo"            "virus"    "pensar"       "hacer"
# 2   "personas"       "donde"       "provincias"  "libertad"     "momento"
# 3    "tendria"       "covid"         "circular"     "tener"  "cuarentena"
# 4     "parece"  "protocolos"            "resto"    "tiempo"     "deberia"
# 5         "la"         "ver"  "responsabilidad"   "todavia"      "riesgo"
# 6    "capital"        "aver"        "trasladar"    "cuidar"       "creer"
# 7   "esencial"   "excepcion"         "propagar"  "cuidarse"        "esto"
# 8     "volver"     "hacerse"            "final"   "turismo"          "se"
# 9  "recuperar"   "descargar"            "basta"  "nosotros"       "tener"
#
#         Topico 10
# 0     "necesario"
# 1     "contagios"
# 2      "pandemia"
# 3        "evitar"
# 4         "salud"
# 5  "buenos_aires"
# 6         "cosas"
# 7       "estaria"
# 8          "fase"
# 9     "cuidarnos"

# %%
def palabras_topico_clave(x):
    topico = ' '.join([x for x in df_palabras_topico[x]])
    doc = nlp(topico)
    palabras = [(token.pos_,token.text) for token in doc]
    palabras_utiles = [x[1] for x in palabras if x[0] in ['NOUN','VERB','ADJ']]
    print( 'Las palabras más relevantes del '+str(x)+' son: '+', '.join(palabras_utiles[:-1])+' y '+palabras_utiles[-1])

# %%
print('Para los '+str(len(list(df_palabras_topico.columns)))+' tópicos encontrados:')
# Out:
# Para los 11 tópicos encontrados:

# %%
for i in list(df_palabras_topico.columns):
    palabras_topico_clave(i)
# Out:
# Las palabras más relevantes del Topico 0 son: tomar, necesarios, gente, acuerdo, ir, recaudos, trabajar, necesitar, cuidados y saber
# Las palabras más relevantes del Topico 1 son: provincias, seria, libre, pais, fronteras y afectadas
# Las palabras más relevantes del Topico 2 son: tener, casos, solo, necesaria, provincias, seguir y peligro
# Las palabras más relevantes del Topico 3 son: control, estricto, isieron, nop, necesidad, perfecto, falto, peores y mudanza
# Las palabras más relevantes del Topico 4 son: querer, estan, llevar, peligroso, viajar, tambien, libres y familiares
# Las palabras más relevantes del Topico 5 son: provincia, personas, tendria, capital, esencial, volver y recuperar
# Las palabras más relevantes del Topico 6 son: controles, covid, protocolos, ver, aver y descargar
# Las palabras más relevantes del Topico 7 son: virus, provincias, circular, resto, responsabilidad, trasladar, propagar, final y basta
# Las palabras más relevantes del Topico 8 son: pensar, libertad, tener, tiempo, todavia, cuidar, cuidarse y turismo
# Las palabras más relevantes del Topico 9 son: contagio, hacer, momento, cuarentena, deberia, riesgo, creer y tener
# Las palabras más relevantes del Topico 10 son: necesario, contagios, pandemia, evitar, salud, buenos_aires, cosas, estaria, fase y cuidarnos

# %%
array_topico=[]
array_valor=[]
for i in corpus:
    dicc_topic = {}
    for x in lda_model.get_document_topics(i):
        dicc_topic[x[0]]=x[1]
    valor_maximo=0
    topico=np.nan
    for item in list(dicc_topic.items()):
        if item[1]>valor_maximo:
            valor_maximo=item[1]
            topico=item[0]
    #print(valor_maximo,topico)
    array_topico.append(topico)
    array_valor.append(valor_maximo)

# %%
opinion_circulacion['Topico']=array_topico
opinion_circulacion['Valor_topico']=array_valor

# %%
# Compute Perplexity
#print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
#coherence_model_lda = CoherenceModel(model=lda_model, texts=data_words_bigrams, dictionary=id2word, coherence='c_v')
#coherence_lda = coherence_model_lda.get_coherence()
#print('\nCoherence Score: ', coherence_lda)

# %% [markdown]
# ## Sentiment

# %%
from textblob import TextBlob

# %%
from urllib.request import urlopen

# %%
url = 'https://raw.githubusercontent.com/meyersebastian/idle/master/negative_words_es.txt'
with open('negative_words_es.txt', 'r',encoding='utf-8') as f:
    texto =f.readlines()

# %%
url = 'https://raw.githubusercontent.com/meyersebastian/idle/master/negative_words_es.txt'
with open('negative_words_es.txt', 'r',encoding='utf-8') as f:
    file2=f.readlines()
url = 'https://raw.githubusercontent.com/meyersebastian/idle/master/positive_words_es.txt'
with open('positive_words_es.txt', 'r',encoding='utf-8') as f:
    file3=f.readlines()

# %%
neg_words=[x.strip('\n').lower() for x in file2]
pos_words=[x.strip('\n').lower() for x in file3]

# %%
def palabras_clave(x):
    doc = nlp(x)
    palabras = [(token.pos_,token.text) for token in doc]
    #print(palabras)
    palabras_utiles = [x[1] for x in palabras if x[0] in ['ADJ','NOUN','NUM','PRON','PROPN','VERB','PART']]
    return ' '.join(palabras_utiles)

# %%
def categoría(x):
    lista=[]
    if x<0.0:
        lista.append('Negativo')
    elif x==0.0:
        lista.append('Neutral')
    else:
        lista.append('Positivo')
    return lista[0]

# %%
opinion_circulacion['Limpio']=opinion_circulacion.circulacion_abierta.apply(lambda x:palabras_clave(x.lower()))

# %%
opinion_circulacion['Neg']=[sum([True for x in tweet.split() if x in neg_words]) for tweet in opinion_circulacion.circulacion_abierta]
opinion_circulacion['Pos']=[sum([True for x in tweet.split() if x in pos_words]) for tweet in opinion_circulacion.circulacion_abierta]

# %%
opinion_circulacion['Palabras']=[sum(True for x in tweet.split()) for tweet in opinion_circulacion.circulacion_abierta]
opinion_circulacion['Ratio']=(opinion_circulacion.Pos-opinion_circulacion.Neg)/opinion_circulacion.Palabras

# %%
opinion_circulacion['Categoría']=opinion_circulacion.Ratio.apply(lambda x: categoría(x))

# %%
opinion_circulacion.Categoría.value_counts()
print('Las respuestas neutrales son '+str(opinion_circulacion.Categoría.value_counts()[0]))
print('Las respuestas negativas son '+str(opinion_circulacion.Categoría.value_counts()[2]))
print('Las respuestas positivas son '+str(opinion_circulacion.Categoría.value_counts()[1]))
# Out:
# Las respuestas neutrales son 310
# Las respuestas negativas son 118
# Las respuestas positivas son 307

# %%
print('Algunos ejemplos de respuestas negativas son: ')
for i in opinion_circulacion.sort_values(by='Ratio',ascending=True).iloc[:5,0]:
    print('- '+i)
# Out:
# Algunos ejemplos de respuestas negativas son:
# - negativo
# - mal
# - innecesario
# - peligro contagio
# - demasiado riesgoso para provincias sin contagios

# %%
print('Algunos ejemplos de respuestas positivas son: ')
for i in opinion_circulacion.sort_values(by='Ratio',ascending=False).iloc[:5,0]:
    print('- '+i)
# Out:
# Algunos ejemplos de respuestas positivas son:
# - positivo
# - bien
# - nada
# - perfecto
# - excelente

# %%
def sumarizacion(df,variable,variable_texto,i):
    print('Categoria: '+i)
    texto='.fin_oracion '.join(df.loc[df[variable]!=i,variable_texto])
    doc = nlp(texto)
    texto_split=texto.split('.fin_oracion ')
    texto_split=[x.lower() for x in texto_split]
    cv = CountVectorizer(stop_words=list(STOP_WORDS))   
    cv_fit=cv.fit_transform(texto_split)    
    word_list = cv.get_feature_names();    
    count_list = cv_fit.toarray().sum(axis=0)
    word_frequency = dict(zip(word_list,count_list))
    val=sorted(word_frequency.values())
    higher_word_frequencies = [word for word,freq in word_frequency.items() if freq in val[-5:]]
    print("Las palabras más frecuentes son " + ', '.join(higher_word_frequencies[:-1])+' y '+higher_word_frequencies[-1])
    print('Algunas respuestas representativas de la categoría son:')
    # gets relative frequencies of words
    higher_frequency = val[-1]
    for words in word_frequency.keys():  
        word_frequency[words] = (word_frequency[words]/higher_frequency)
    sentence_rank={}
    for sent in texto_split:
        for word in sent.split() :       
            if word in word_frequency.keys():            
                if sent in sentence_rank.keys():
                    sentence_rank[sent]+=word_frequency[word]
                else:
                    sentence_rank[sent]=word_frequency[word]
    top_sentences=(sorted(sentence_rank.values())[::-1])
    top_sent=top_sentences[:20]
    summary=[]
    strength_lista = []
    for sentence,strength in sentence_rank.items():  
        if strength in top_sent:
            summary.append(sentence)
            strength_lista.append(strength)
        else:
            continue
    df_sent=pd.DataFrame(list(zip(summary,strength_lista)),columns=['Sentence','Score'])
    df_sent=df_sent.sort_values(by=['Score'],ascending=False).reset_index()
    numero=0
    for i in range(len(df_sent)):
        if numero<3:    
            if (len(df_sent.Sentence[i])>30)&(len(df_sent.Sentence[i])<1000):
                print('- '+df_sent.Sentence[i])
                numero+=1
                #print('-----')
        else:
            break
    print('\n')

# %%
for i in ['Positivo','Negativo']:  
    sumarizacion(opinion_circulacion,'Categoría','circulacion_abierta',i)
# Out:
# Categoria: Positivo
# Las palabras más frecuentes son casos, circulacion, circular, provincias y virus
# Algunas respuestas representativas de la categoría son:
# - creo que despues de 100 dias de cuarentena, ya deberia estar habilitada la circulacion en micros de larga distancia asi como en auto, sobre todo entre provincias que ya alcanzaron la fase 5, o entre ciudades o localidades tambien en fase 5.  solo no estaria de acuerdo en el contacto de provincias de fase 5 con otras que estan en una fase inferior. no me parece justo que en donde hicimos las cosas bien debamos seguir esperando que habran las provincias o que habiliten los micros de larga distancia por culpa de una sola provincia que hicieron todo mal.
# - deberia tomarse en cuenta que si hay localidades limitrofes donde no hay circulacion del virus y que sean de provincias distintas, tranquilamente podrian circular las personas en esas localidades y a tambien ir a las ciudades capitales donde el virus este manejado
# - me encantaria viajar a la patagonia donde vive uno de los hijos, pero siendo q caba esta tan poblada de gente infectada por el virus, la circulacion hacia alla seria terrible x el posible contagio. hasta q no haya casos no. pero la circulacion entre provincias q no tienen casos la veo muy bien, obviamente
#
#
# Categoria: Negativo
# Las palabras más frecuentes son casos, circulacion, circular, controles y provincias
# Algunas respuestas representativas de la categoría son:
# - no me parece oportuno , mi provincia esta rodeado de otras provincias con mayor numeros de persona infectadas , a pesar que mi provincia cuenta con 73 casos positivos , 63 son personas que han vuelto de ciudades con mucha circulacion viral , y 10 ya se contagiaron porque son personal de la institucion , quienes estaban a cargo de las personas que cumplian con la cuarentena correspondiente!!!
# - no me parece seguro circulacion entre provincias , ya que hay provincias que se encuentran libres de infectados, y provincias que no, estarian esparciendo el virus. y esta seri muy peligroso
# - estoy en desacuerdo porque hay provincias que no tienen tantos casos positivos de covid y otras si al fomentar la circulacion abra mas casos positivos de covid, nuestro sistema de salud se veria mas afectado de lo que esta.  sobre todo por la gran poblacion de personas humildes y en situacion de calle que se les dificulta mas cumplir con todas las medidas preventivas.
